# %%
import sys
import os

sys.path.append(os.path.abspath("src"))

# %%
from blackjack import Card, CardValue, Suit, Game, Hand
game = Game(5, vocal=True)
game.takeBets()
game.dealInitialCards()
# Out:
# Game started, deck reshuffled

# %%
game.voiceHand(game.players[0], 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 game.voiceHand(game.players[0], 1)
#
# NameError: name 'game' is not defined

# %%
game.hit(game.players[3], 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 game.hit(game.players[3], 0)
#
# NameError: name 'game' is not defined

# %%
game.hit(game.players[1], 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 game.hit(game.players[1], 0)
#
# NameError: name 'game' is not defined

# %%
game.double(game.players[1], 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 game.double(game.players[1], 0)
#
# NameError: name 'game' is not defined

# %%
h = Hand()
K = Card(Suit.CLUBS, CardValue.KING)
A = Card(Suit.CLUBS, CardValue.ACE)
h.cards = [K, A]

# %%
h.isBlackjack()
# Out:
# True
