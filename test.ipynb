# %%
import sys
import os

sys.path.append(os.path.abspath("src"))

# %%
from blackjack import Card, CardValue, Suit, Game, Hand, Moves, GameState
game = Game(5, vocal=True)
game.takeBets()
game.dealInitialCards()
# Out:
# Game started, deck reshuffled
# Dealer's card:    K♦
# Player 1, hand 1: Q♣ A♣ | 21
# Player 2, hand 1: 8♣ 6♠ | 14
# Player 3, hand 1: 8♥ 5♦ | 13
# Player 4, hand 1: 2♥ A♥ | 13
# Player 5, hand 1: 3♦ 9♦ | 12

# %%
def Test(hand):
    a = input()
    if a == 'hit': return Moves.HIT
    if a == 'stand': return Moves.STAND
    if a == 'double': return Moves.DOUBLE
    if a == 'split': return Moves.SPLIT
    return Test(hand)

# %%
while game.game_state == G
# Out:
# All players have been dealt
# Dealer's cards: K♦ 4♥ | 14

# %%
game.voiceHand(game.dealer.hand)
# Out:
# 'K♦ 4♥ 7♣ | 21'
