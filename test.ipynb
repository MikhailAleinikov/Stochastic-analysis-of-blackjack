# %%
import sys
import os

sys.path.append(os.path.abspath("src"))

# %%
 from blackjack import Card, CardValue, Suit, Game, Hand
game = Game(5)
game.startGame()
# Out:
# Game started, deck reshuffled
# Dealer's card:    3♥
# Player 1, hand 1: 2♦ 2♠ | 4
# Player 2, hand 1: 6♥ 4♣ | 10
# Player 3, hand 1: 8♣ 7♠ | 15
# Player 4, hand 1: 2♣ 6♦ | 8
# Player 5, hand 1: 4♠ T♥ | 14

# %%
game.split(game.players[0], 0)

# %%
game.voiceHand(game.players[0], 1)
# Out:
# Player 1, hand 2: 2♦ | 2

# %%
game.hit(game.players[3], 0)
# Out:
# Player 4 cannot hit anymore at hand 1

# %%
game.hit(game.players[1], 0)
# Out:
# Player 2 cannot hit anymore at hand 1

# %%
game.double(game.players[1], 0)
# Out:
# Player 2 chose 'double' at hand 1
# Player 2, hand 1: 6♥ 4♣ K♦ 5♥ | 25 BUST
