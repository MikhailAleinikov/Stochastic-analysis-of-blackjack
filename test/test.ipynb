# %%
import sys
import os

import numpy

sys.path.append(os.path.abspath("../src"))

# %%
from blackjack import Card, CardValue, Suit, Game, Hand, Moves, GameState
from blackjack.strategy import testStrategy, randomStrategy, fixedStrategy
from blackjack.analysis import Logger, runOneGame
logger = Logger(1)
for i in range(1000000):
    print(i)
    runOneGame([fixedStrategy for i in range(5)], vocal=False, logger=logger, round_id=i)

# %%
logger.save_rewards_csv("test.csv")
